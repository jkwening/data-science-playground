# %% [markdown]
# # [Random Forest for Time Series Forecasting](https://machinelearningmastery.com/random-forest-for-time-series-forecasting/)
#
# Random Forest can also be used for time series forecasting, although it requires that the time series dataset be transformed into a supervised learning problem first. It also requires the use of a specialized technique for evaluating the model called [walk-forward validation](https://en.wikipedia.org/wiki/Walk_forward_optimization), as evaluating the model using k-fold cross validation would result in optimistically biased results.

# %%
import os
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error

# %%
# get data
TEST_CSV = 'test.csv'  # no data snooping!
TRAIN_CSV = 'train.csv'
train_df = pd.read_csv(TRAIN_CSV)
train_df
# Out:
#        row_id        date  country       store  \
# 0           0  2017-01-01  Belgium  KaggleMart
# 1           1  2017-01-01  Belgium  KaggleMart
# 2           2  2017-01-01  Belgium  KaggleMart
# 3           3  2017-01-01  Belgium  KaggleMart
# 4           4  2017-01-01  Belgium  KaggleRama
# ...       ...         ...      ...         ...
# 70123   70123  2020-12-31    Spain  KaggleMart
# 70124   70124  2020-12-31    Spain  KaggleRama
# 70125   70125  2020-12-31    Spain  KaggleRama
# 70126   70126  2020-12-31    Spain  KaggleRama
# 70127   70127  2020-12-31    Spain  KaggleRama
#
#                                 product  num_sold
# 0            Kaggle Advanced Techniques       663
# 1                Kaggle Getting Started       615
# 2                    Kaggle Recipe Book       480
# 3      Kaggle for Kids: One Smart Goose       710
# 4            Kaggle Advanced Techniques       240
# ...                                 ...       ...
# 70123  Kaggle for Kids: One Smart Goose       614
# 70124        Kaggle Advanced Techniques       215
# 70125            Kaggle Getting Started       158
# 70126                Kaggle Recipe Book       135
# 70127  Kaggle for Kids: One Smart Goose       202
#
# [70128 rows x 6 columns]

# %% [markdown]
# ## [Convert Time Series Data to Supervised Representation](https://machinelearningmastery.com/convert-time-series-supervised-learning-problem-python/)
#
# We need to reframe the dataset into features from previous day, including previous day target, mapping it to next days target.
#
# This is a little trickier for this dataset since we're not looking at features for a single book and predicting sales for it overtime. This is more complex because we're predicting sales for four different book products, sold across two different stores, and six countries. So to reframe as supervised model, we will need to convert 4 x 2 x 6 different subsets into single reframed dataset for model training across four years. The input for future predictions will need to handle any of the different feature types to predict appropriately.

# %%
def series_to_supervised(train_df: pd.DataFrame) -> pd.DataFrame:
    df = train_df.copy()
    df['uuid'] = [
        f'{row["country"]}_{row["store"]}_{row["product"]}'
        for _, row in df.iterrows()
    ]
    df.sort_values(by=['uuid', 'date'], inplace=True)
    mod_df = df.shift(1).rename(columns={
        'date': 'prev_date', 'num_sold': 'prev_num_sold'
    })
    mod_df = pd.concat([mod_df, df.loc[:, ['num_sold', 'date']]], axis=1)
    mod_df = mod_df.loc[mod_df.date != '2017-01-01', :]
    return mod_df

# %%
mod_train_df = series_to_supervised(train_df)
mod_train_df
# Out:
#         row_id   prev_date  country       store  \
# 48         0.0  2017-01-01  Belgium  KaggleMart
# 96        48.0  2017-01-02  Belgium  KaggleMart
# 144       96.0  2017-01-03  Belgium  KaggleMart
# 192      144.0  2017-01-04  Belgium  KaggleMart
# 240      192.0  2017-01-05  Belgium  KaggleMart
# ...        ...         ...      ...         ...
# 69935  69887.0  2020-12-26    Spain  KaggleRama
# 69983  69935.0  2020-12-27    Spain  KaggleRama
# 70031  69983.0  2020-12-28    Spain  KaggleRama
# 70079  70031.0  2020-12-29    Spain  KaggleRama
# 70127  70079.0  2020-12-30    Spain  KaggleRama
#
#                                 product  prev_num_sold  \
# 48           Kaggle Advanced Techniques          663.0
# 96           Kaggle Advanced Techniques          514.0
# 144          Kaggle Advanced Techniques          549.0
# 192          Kaggle Advanced Techniques          477.0
# 240          Kaggle Advanced Techniques          447.0
# ...                                 ...            ...
# 69935  Kaggle for Kids: One Smart Goose          187.0
# 69983  Kaggle for Kids: One Smart Goose          204.0
# 70031  Kaggle for Kids: One Smart Goose          212.0
# 70079  Kaggle for Kids: One Smart Goose          242.0
# 70127  Kaggle for Kids: One Smart Goose          239.0
#
#                                                     uuid  num_sold        date
# 48         Belgium_KaggleMart_Kaggle Advanced Techniques       514  2017-01-02
# 96         Belgium_KaggleMart_Kaggle Advanced Techniques       549  2017-01-03
# 144        Belgium_KaggleMart_Kaggle Advanced Techniques       477  2017-01-04
# 192        Belgium_KaggleMart_Kaggle Advanced Techniques       447  2017-01-05
# 240        Belgium_KaggleMart_Kaggle Advanced Techniques       431  2017-01-06
# ...                                                  ...       ...         ...
# 69935  Spain_KaggleRama_Kaggle for Kids: One Smart Goose       204  2020-12-27
# 69983  Spain_KaggleRama_Kaggle for Kids: One Smart Goose       212  2020-12-28
# 70031  Spain_KaggleRama_Kaggle for Kids: One Smart Goose       242  2020-12-29
# 70079  Spain_KaggleRama_Kaggle for Kids: One Smart Goose       239  2020-12-30
# 70127  Spain_KaggleRama_Kaggle for Kids: One Smart Goose       202  2020-12-31
#
# [70080 rows x 9 columns]

# %%
mod_train_df.reset_index().head(1461)
# Out:
#       index   row_id   prev_date  country       store  \
# 0        48      0.0  2017-01-01  Belgium  KaggleMart
# 1        96     48.0  2017-01-02  Belgium  KaggleMart
# 2       144     96.0  2017-01-03  Belgium  KaggleMart
# 3       192    144.0  2017-01-04  Belgium  KaggleMart
# 4       240    192.0  2017-01-05  Belgium  KaggleMart
# ...     ...      ...         ...      ...         ...
# 1456  69936  69888.0  2020-12-27  Belgium  KaggleMart
# 1457  69984  69936.0  2020-12-28  Belgium  KaggleMart
# 1458  70032  69984.0  2020-12-29  Belgium  KaggleMart
# 1459  70080  70032.0  2020-12-30  Belgium  KaggleMart
# 1460     49      1.0  2017-01-01  Belgium  KaggleMart
#
#                          product  prev_num_sold  \
# 0     Kaggle Advanced Techniques          663.0
# 1     Kaggle Advanced Techniques          514.0
# 2     Kaggle Advanced Techniques          549.0
# 3     Kaggle Advanced Techniques          477.0
# 4     Kaggle Advanced Techniques          447.0
# ...                          ...            ...
# 1456  Kaggle Advanced Techniques          574.0
# 1457  Kaggle Advanced Techniques          625.0
# 1458  Kaggle Advanced Techniques          597.0
# 1459  Kaggle Advanced Techniques          632.0
# 1460      Kaggle Getting Started          615.0
#
#                                                uuid  num_sold        date
# 0     Belgium_KaggleMart_Kaggle Advanced Techniques       514  2017-01-02
# 1     Belgium_KaggleMart_Kaggle Advanced Techniques       549  2017-01-03
# 2     Belgium_KaggleMart_Kaggle Advanced Techniques       477  2017-01-04
# 3     Belgium_KaggleMart_Kaggle Advanced Techniques       447  2017-01-05
# 4     Belgium_KaggleMart_Kaggle Advanced Techniques       431  2017-01-06
# ...                                             ...       ...         ...
# 1456  Belgium_KaggleMart_Kaggle Advanced Techniques       625  2020-12-28
# 1457  Belgium_KaggleMart_Kaggle Advanced Techniques       597  2020-12-29
# 1458  Belgium_KaggleMart_Kaggle Advanced Techniques       632  2020-12-30
# 1459  Belgium_KaggleMart_Kaggle Advanced Techniques       616  2020-12-31
# 1460      Belgium_KaggleMart_Kaggle Getting Started       408  2017-01-02
#
# [1461 rows x 10 columns]

# %%
mod_train_df.reset_index().tail(1461)
# Out:
#        index   row_id   prev_date country       store  \
# 68619  70126  70078.0  2020-12-30   Spain  KaggleRama
# 68620     95     47.0  2017-01-01   Spain  KaggleRama
# 68621    143     95.0  2017-01-02   Spain  KaggleRama
# 68622    191    143.0  2017-01-03   Spain  KaggleRama
# 68623    239    191.0  2017-01-04   Spain  KaggleRama
# ...      ...      ...         ...     ...         ...
# 70075  69935  69887.0  2020-12-26   Spain  KaggleRama
# 70076  69983  69935.0  2020-12-27   Spain  KaggleRama
# 70077  70031  69983.0  2020-12-28   Spain  KaggleRama
# 70078  70079  70031.0  2020-12-29   Spain  KaggleRama
# 70079  70127  70079.0  2020-12-30   Spain  KaggleRama
#
#                                 product  prev_num_sold  \
# 68619                Kaggle Recipe Book          153.0
# 68620  Kaggle for Kids: One Smart Goose          181.0
# 68621  Kaggle for Kids: One Smart Goose          123.0
# 68622  Kaggle for Kids: One Smart Goose          125.0
# 68623  Kaggle for Kids: One Smart Goose          110.0
# ...                                 ...            ...
# 70075  Kaggle for Kids: One Smart Goose          187.0
# 70076  Kaggle for Kids: One Smart Goose          204.0
# 70077  Kaggle for Kids: One Smart Goose          212.0
# 70078  Kaggle for Kids: One Smart Goose          242.0
# 70079  Kaggle for Kids: One Smart Goose          239.0
#
#                                                     uuid  num_sold        date
# 68619                Spain_KaggleRama_Kaggle Recipe Book       135  2020-12-31
# 68620  Spain_KaggleRama_Kaggle for Kids: One Smart Goose       123  2017-01-02
# 68621  Spain_KaggleRama_Kaggle for Kids: One Smart Goose       125  2017-01-03
# 68622  Spain_KaggleRama_Kaggle for Kids: One Smart Goose       110  2017-01-04
# 68623  Spain_KaggleRama_Kaggle for Kids: One Smart Goose       104  2017-01-05
# ...                                                  ...       ...         ...
# 70075  Spain_KaggleRama_Kaggle for Kids: One Smart Goose       204  2020-12-27
# 70076  Spain_KaggleRama_Kaggle for Kids: One Smart Goose       212  2020-12-28
# 70077  Spain_KaggleRama_Kaggle for Kids: One Smart Goose       242  2020-12-29
# 70078  Spain_KaggleRama_Kaggle for Kids: One Smart Goose       239  2020-12-30
# 70079  Spain_KaggleRama_Kaggle for Kids: One Smart Goose       202  2020-12-31
#
# [1461 rows x 10 columns]

# %% [markdown]
# ## One-hot Encode Categorical Cols
#
# Need to one-hot encode `country`, `store`, and `product` columns for used in modeling.

# %%
ohe_train_df = pd.get_dummies(
    data=mod_train_df, prefix=['country', 'store', 'product'],
    columns=['country', 'store', 'product']
)
ohe_train_df
# Out:
#         row_id   prev_date  prev_num_sold  \
# 48         0.0  2017-01-01          663.0
# 96        48.0  2017-01-02          514.0
# 144       96.0  2017-01-03          549.0
# 192      144.0  2017-01-04          477.0
# 240      192.0  2017-01-05          447.0
# ...        ...         ...            ...
# 69935  69887.0  2020-12-26          187.0
# 69983  69935.0  2020-12-27          204.0
# 70031  69983.0  2020-12-28          212.0
# 70079  70031.0  2020-12-29          242.0
# 70127  70079.0  2020-12-30          239.0
#
#                                                     uuid  num_sold  \
# 48         Belgium_KaggleMart_Kaggle Advanced Techniques       514
# 96         Belgium_KaggleMart_Kaggle Advanced Techniques       549
# 144        Belgium_KaggleMart_Kaggle Advanced Techniques       477
# 192        Belgium_KaggleMart_Kaggle Advanced Techniques       447
# 240        Belgium_KaggleMart_Kaggle Advanced Techniques       431
# ...                                                  ...       ...
# 69935  Spain_KaggleRama_Kaggle for Kids: One Smart Goose       204
# 69983  Spain_KaggleRama_Kaggle for Kids: One Smart Goose       212
# 70031  Spain_KaggleRama_Kaggle for Kids: One Smart Goose       242
# 70079  Spain_KaggleRama_Kaggle for Kids: One Smart Goose       239
# 70127  Spain_KaggleRama_Kaggle for Kids: One Smart Goose       202
#
#              date  country_Belgium  country_France  country_Germany  \
# 48     2017-01-02                1               0                0
# 96     2017-01-03                1               0                0
# 144    2017-01-04                1               0                0
# 192    2017-01-05                1               0                0
# 240    2017-01-06                1               0                0
# ...           ...              ...             ...              ...
# 69935  2020-12-27                0               0                0
# 69983  2020-12-28                0               0                0
# 70031  2020-12-29                0               0                0
# 70079  2020-12-30                0               0                0
# 70127  2020-12-31                0               0                0
#
#        country_Italy  country_Poland  country_Spain  store_KaggleMart  \
# 48                 0               0              0                 1
# 96                 0               0              0                 1
# 144                0               0              0                 1
# 192                0               0              0                 1
# 240                0               0              0                 1
# ...              ...             ...            ...               ...
# 69935              0               0              1                 0
# 69983              0               0              1                 0
# 70031              0               0              1                 0
# 70079              0               0              1                 0
# 70127              0               0              1                 0
#
#        store_KaggleRama  product_Kaggle Advanced Techniques  \
# 48                    0                                   1
# 96                    0                                   1
# 144                   0                                   1
# 192                   0                                   1
# 240                   0                                   1
# ...                 ...                                 ...
# 69935                 1                                   0
# 69983                 1                                   0
# 70031                 1                                   0
# 70079                 1                                   0
# 70127                 1                                   0
#
#        product_Kaggle Getting Started  product_Kaggle Recipe Book  \
# 48                                  0                           0
# 96                                  0                           0
# 144                                 0                           0
# 192                                 0                           0
# 240                                 0                           0
# ...                               ...                         ...
# 69935                               0                           0
# 69983                               0                           0
# 70031                               0                           0
# 70079                               0                           0
# 70127                               0                           0
#
#        product_Kaggle for Kids: One Smart Goose
# 48                                            0
# 96                                            0
# 144                                           0
# 192                                           0
# 240                                           0
# ...                                         ...
# 69935                                         1
# 69983                                         1
# 70031                                         1
# 70079                                         1
# 70127                                         1
#
# [70080 rows x 18 columns]

# %% [markdown]
# ## Generate Model Ready Dataset
#
# Now that we have supervised representation along with one-hot-encoding of necessary categorical features, before we can apply to random forest model, we need drop all unnecessary columns and convert to matrix (numpy array): `indices`, `row_id`, `prev_date`, `uuid`, and `date`.
#
# The only thing that should remain along with one-hot-encoded catecorigal features are:
# - `prev_num_sold` which represents X, which now completes the sliding window inputs needed for walk-forward validation
# - `num_sold` which represents y, the target for each sliding window input

# %%
# re-order columns so it will be easy to subset into: uuid - time group, features, & target
COL_MUNGED_DATA = [
    'uuid', 'prev_date', 'date',
    'prev_num_sold', 'country_Belgium', 'country_France', 'country_Germany', 'country_Italy',
    'country_Poland', 'country_Spain', 'store_KaggleMart',
    'store_KaggleRama', 'product_Kaggle Advanced Techniques',
    'product_Kaggle Getting Started', 'product_Kaggle Recipe Book',
    'product_Kaggle for Kids: One Smart Goose', 'num_sold'
]
COL_MUNGED_DATA
# Out:
# ['uuid',
#  'prev_date',
#  'date',
#  'prev_num_sold',
#  'country_Belgium',
#  'country_France',
#  'country_Germany',
#  'country_Italy',
#  'country_Poland',
#  'country_Spain',
#  'store_KaggleMart',
#  'store_KaggleRama',
#  'product_Kaggle Advanced Techniques',
#  'product_Kaggle Getting Started',
#  'product_Kaggle Recipe Book',
#  'product_Kaggle for Kids: One Smart Goose',
#  'num_sold']

# %%
# create index to column name mapping to facilitate reconciling
IDX_COL_NAME_MAP = {i: col for i, col in enumerate(COL_MUNGED_DATA)}
IDX_COL_NAME_MAP
# Out:
# {0: 'uuid',
#  1: 'prev_date',
#  2: 'date',
#  3: 'prev_num_sold',
#  4: 'country_Belgium',
#  5: 'country_France',
#  6: 'country_Germany',
#  7: 'country_Italy',
#  8: 'country_Poland',
#  9: 'country_Spain',
#  10: 'store_KaggleMart',
#  11: 'store_KaggleRama',
#  12: 'product_Kaggle Advanced Techniques',
#  13: 'product_Kaggle Getting Started',
#  14: 'product_Kaggle Recipe Book',
#  15: 'product_Kaggle for Kids: One Smart Goose',
#  16: 'num_sold'}

# %% [markdown]
# Based on indices, columns:
# - 0 - 2: identifier and date group
# - 3 - 15: feature set
# - 16: target

# %%
munged_df = ohe_train_df.loc[:, COL_MUNGED_DATA]
munged_df
# Out:
#                                                     uuid   prev_date  \
# 48         Belgium_KaggleMart_Kaggle Advanced Techniques  2017-01-01
# 96         Belgium_KaggleMart_Kaggle Advanced Techniques  2017-01-02
# 144        Belgium_KaggleMart_Kaggle Advanced Techniques  2017-01-03
# 192        Belgium_KaggleMart_Kaggle Advanced Techniques  2017-01-04
# 240        Belgium_KaggleMart_Kaggle Advanced Techniques  2017-01-05
# ...                                                  ...         ...
# 69935  Spain_KaggleRama_Kaggle for Kids: One Smart Goose  2020-12-26
# 69983  Spain_KaggleRama_Kaggle for Kids: One Smart Goose  2020-12-27
# 70031  Spain_KaggleRama_Kaggle for Kids: One Smart Goose  2020-12-28
# 70079  Spain_KaggleRama_Kaggle for Kids: One Smart Goose  2020-12-29
# 70127  Spain_KaggleRama_Kaggle for Kids: One Smart Goose  2020-12-30
#
#              date  prev_num_sold  country_Belgium  country_France  \
# 48     2017-01-02          663.0                1               0
# 96     2017-01-03          514.0                1               0
# 144    2017-01-04          549.0                1               0
# 192    2017-01-05          477.0                1               0
# 240    2017-01-06          447.0                1               0
# ...           ...            ...              ...             ...
# 69935  2020-12-27          187.0                0               0
# 69983  2020-12-28          204.0                0               0
# 70031  2020-12-29          212.0                0               0
# 70079  2020-12-30          242.0                0               0
# 70127  2020-12-31          239.0                0               0
#
#        country_Germany  country_Italy  country_Poland  country_Spain  \
# 48                   0              0               0              0
# 96                   0              0               0              0
# 144                  0              0               0              0
# 192                  0              0               0              0
# 240                  0              0               0              0
# ...                ...            ...             ...            ...
# 69935                0              0               0              1
# 69983                0              0               0              1
# 70031                0              0               0              1
# 70079                0              0               0              1
# 70127                0              0               0              1
#
#        store_KaggleMart  store_KaggleRama  product_Kaggle Advanced Techniques  \
# 48                    1                 0                                   1
# 96                    1                 0                                   1
# 144                   1                 0                                   1
# 192                   1                 0                                   1
# 240                   1                 0                                   1
# ...                 ...               ...                                 ...
# 69935                 0                 1                                   0
# 69983                 0                 1                                   0
# 70031                 0                 1                                   0
# 70079                 0                 1                                   0
# 70127                 0                 1                                   0
#
#        product_Kaggle Getting Started  product_Kaggle Recipe Book  \
# 48                                  0                           0
# 96                                  0                           0
# 144                                 0                           0
# 192                                 0                           0
# 240                                 0                           0
# ...                               ...                         ...
# 69935                               0                           0
# 69983                               0                           0
# 70031                               0                           0
# 70079                               0                           0
# 70127                               0                           0
#
#        product_Kaggle for Kids: One Smart Goose  num_sold
# 48                                            0       514
# 96                                            0       549
# 144                                           0       477
# 192                                           0       447
# 240                                           0       431
# ...                                         ...       ...
# 69935                                         1       204
# 69983                                         1       212
# 70031                                         1       242
# 70079                                         1       239
# 70127                                         1       202
#
# [70080 rows x 17 columns]

# %%
munged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 70080 entries, 48 to 70127
# Data columns (total 17 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   uuid                                      70080 non-null  object
#  1   prev_date                                 70080 non-null  object
#  2   date                                      70080 non-null  object
#  3   prev_num_sold                             70080 non-null  float64
#  4   country_Belgium                           70080 non-null  uint8
#  5   country_France                            70080 non-null  uint8
#  6   country_Germany                           70080 non-null  uint8
#  7   country_Italy                             70080 non-null  uint8
#  8   country_Poland                            70080 non-null  uint8
#  9   country_Spain                             70080 non-null  uint8
#  10  store_KaggleMart                          70080 non-null  uint8
#  11  store_KaggleRama                          70080 non-null  uint8
#  12  product_Kaggle Advanced Techniques        70080 non-null  uint8
#  13  product_Kaggle Getting Started            70080 non-null  uint8
#  14  product_Kaggle Recipe Book                70080 non-null  uint8
#  15  product_Kaggle for Kids: One Smart Goose  70080 non-null  uint8
#  16  num_sold                                  70080 non-null  int64
# dtypes: float64(1), int64(1), object(3), uint8(12)
# memory usage: 4.0+ MB

# %% [markdown]
# ## Walk-forward Validation
#
# The next step is to define evaluation methodology for this dataset, while keeping in mind the complexity and non-linearity between `uuid`s.
#
# Recall, the task is to predict the corresponding item sales for each date-country-store-item combination. So for each date in 2021, we want to predict the corresponding country-store-item (uuid) sales using the dataset spanning 2016 - 2020.
#
# Note:
# In walk-forward validation, the dataset is first split into train and test sets by selecting a cut point, e.g. all data except the last 12 months is used for training and the last 12 months is used for testing.
#
# If we are interested in making a one-step forecast, e.g. one month, then we can evaluate the model by training on the training dataset and predicting the first step in the test dataset. We can then add the real observation from the test set to the training dataset, refit the model, then have the model predict the second step in the test dataset.
#
# Repeating this process for the entire test dataset will give a one-step prediction for the entire test dataset from which an error measure can be calculated to evaluate the skill of the model.

# %%
# total number of date-country-store-item combination for given year
len(munged_df.uuid.unique()) * 365
# Out:
# 17520

# %% [markdown]
# ### Naive Approach
#
# The simplest approach is to use 2016 - 2019 dataset as training set and 2020 data as the test set. Then apply the walk-forward validation approach for each day in 2020 to train the model for predicting each date-country-store-item combination in 2021.
#
# For this approach, we can think of single training epoch as walking through all date-country-store-item combinations in 2020. Which is 17,520 steps.

# %%
def train_test_split(data: pd.DataFrame, date_cut: str) -> tuple:
    train_df = data[data.date < date_cut]
    test_df = data[data.date >= date_cut]
    np_train = train_df.iloc[: , 3:].to_numpy()
    np_test = test_df.iloc[:, 3:].to_numpy()
    return np_train, np_test

# %%
def random_forest_forecast(train: list, test_x: np.array) -> float:
    train = np.asarray(train)
    train_x, train_y = train[:, :-1], train[:, -1]
    # fit model
    model = RandomForestRegressor(n_estimators=1000)
    model.fit(train_x, train_y)
    # make one-step prediction
    y_hat = model.predict([test_x])
    return y_hat[0]

# %%
def walk_forward_validation(data: pd.DataFrame, date_cut: str) -> tuple:
    predictions = []
    train, test = train_test_split(data, date_cut)
    # seed history with training dataset
    history = [x for x in train]
    # perform walk forward steps
    for i in range(len(test)):
        test_x, test_y = test[i, :-1], test[i, -1]
        y_hat = random_forest_forecast(history, test_x)
        predictions.append(y_hat)
        # add actual observation to history for the next loop
        history.append(test[i])
        print('expected=%.1f, predicted=%.1f' % (test_y, y_hat))
    # estimate prediction error
    error = mean_absolute_error(test[:, -1], predictions)
    return error, test[:, 1], predictions

# %%
error, targets, predictions = walk_forward_validation(munged_df, '2020-01-01')
error, targets, predictions
# Out:
# expected=501.0, predicted=530.9
# expected=452.0, predicted=529.5
# expected=452.0, predicted=475.6
# expected=517.0, predicted=472.1
# expected=503.0, predicted=516.0
# expected=445.0, predicted=511.4
# expected=445.0, predicted=450.9
# expected=375.0, predicted=449.1
# expected=386.0, predicted=375.3
# expected=444.0, predicted=376.9
# expected=441.0, predicted=451.2
# expected=488.0, predicted=446.1
# expected=385.0, predicted=501.9
# expected=417.0, predicted=398.2
# expected=399.0, predicted=416.1
# expected=383.0, predicted=379.5
# expected=439.0, predicted=388.1
# expected=440.0, predicted=439.3
# expected=473.0, predicted=455.4
# expected=383.0, predicted=458.7
# expected=405.0, predicted=398.3
# expected=382.0, predicted=405.9
# expected=433.0, predicted=324.1
# expected=429.0, predicted=394.6
# expected=452.0, predicted=435.8
# expected=462.0, predicted=476.5
# expected=397.0, predicted=483.5
# expected=406.0, predicted=397.1
# expected=386.0, predicted=437.0
# expected=416.0, predicted=391.1
# expected=437.0, predicted=436.1
# expected=480.0, predicted=419.2
# expected=482.0, predicted=534.2
# expected=407.0, predicted=465.3
# expected=418.0, predicted=418.9
# expected=407.0, predicted=428.7
# expected=418.0, predicted=417.6
# expected=437.0, predicted=425.4
# expected=491.0, predicted=428.2
# expected=515.0, predicted=448.1
# expected=397.0, predicted=572.4
# expected=395.0, predicted=399.5
# expected=482.0, predicted=407.5
# expected=412.0, predicted=439.3
# expected=453.0, predicted=432.7
# expected=485.0, predicted=450.8
# expected=531.0, predicted=482.5
# expected=449.0, predicted=497.1
# expected=423.0, predicted=454.3
# expected=444.0, predicted=428.7
# expected=489.0, predicted=449.9
# expected=465.0, predicted=478.1
# expected=505.0, predicted=480.1
# expected=545.0, predicted=401.7
# expected=468.0, predicted=575.4
# expected=385.0, predicted=488.9
# expected=446.0, predicted=403.8
# expected=427.0, predicted=449.4
# expected=447.0, predicted=438.8
# expected=529.0, predicted=451.2
# expected=445.0, predicted=528.8
# expected=392.0, predicted=434.0
# expected=386.0, predicted=393.7
# expected=376.0, predicted=394.2
# expected=397.0, predicted=383.9
# expected=408.0, predicted=397.6
# expected=468.0, predicted=428.0
# expected=487.0, predicted=463.3
# expected=373.0, predicted=490.8
# expected=418.0, predicted=403.0
# expected=397.0, predicted=427.2
# expected=420.0, predicted=398.7
# expected=400.0, predicted=446.0
# expected=478.0, predicted=382.6
# expected=486.0, predicted=474.2
# expected=396.0, predicted=527.0
# expected=392.0, predicted=425.0
# expected=385.0, predicted=390.9
# expected=436.0, predicted=412.5
# expected=396.0, predicted=440.0
# expected=470.0, predicted=421.4
# expected=454.0, predicted=474.9
# expected=419.0, predicted=462.4
# expected=408.0, predicted=410.4
# expected=351.0, predicted=435.8
# expected=394.0, predicted=356.0
# expected=448.0, predicted=424.1
# expected=451.0, predicted=447.6
# expected=479.0, predicted=457.0
# expected=412.0, predicted=483.6
# expected=419.0, predicted=436.4
# expected=347.0, predicted=411.4
# expected=328.0, predicted=340.5
# expected=356.0, predicted=340.1
# expected=383.0, predicted=370.7
# expected=428.0, predicted=399.1
# expected=332.0, predicted=414.3
# expected=309.0, predicted=312.0
# expected=309.0, predicted=327.4
# expected=319.0, predicted=323.9
# expected=364.0, predicted=315.4
# expected=338.0, predicted=385.6
# expected=339.0, predicted=364.1
# expected=333.0, predicted=353.0
# expected=350.0, predicted=306.2
# expected=375.0, predicted=363.5
# expected=380.0, predicted=378.0
# expected=371.0, predicted=405.8
# expected=381.0, predicted=387.3
# expected=433.0, predicted=384.8
# expected=336.0, predicted=403.5
# expected=336.0, predicted=342.7
# expected=331.0, predicted=341.2
# expected=328.0, predicted=343.5
# expected=332.0, predicted=342.9
# expected=374.0, predicted=308.5
# expected=392.0, predicted=382.1
# expected=317.0, predicted=389.4
# expected=326.0, predicted=327.1
# expected=331.0, predicted=333.4
# expected=336.0, predicted=341.2
# expected=367.0, predicted=340.7
# expected=428.0, predicted=392.9
# expected=426.0, predicted=401.8
# expected=395.0, predicted=440.9
# expected=392.0, predicted=424.4
# expected=392.0, predicted=375.6
# expected=385.0, predicted=377.3
# expected=421.0, predicted=416.0
# expected=439.0, predicted=433.8
# expected=440.0, predicted=438.9
# expected=313.0, predicted=458.6
# expected=349.0, predicted=335.3
# expected=372.0, predicted=357.7
# expected=346.0, predicted=381.7
# expected=358.0, predicted=374.3
# expected=388.0, predicted=372.1
# expected=403.0, predicted=410.4
# expected=366.0, predicted=393.8
# expected=359.0, predicted=367.5
# expected=367.0, predicted=374.3
# expected=334.0, predicted=398.1
# expected=369.0, predicted=336.0
# expected=450.0, predicted=376.4
# expected=465.0, predicted=444.2
# expected=398.0, predicted=483.1
# expected=406.0, predicted=427.4
# expected=365.0, predicted=429.7
# expected=362.0, predicted=349.2
# expected=344.0, predicted=355.1
# expected=401.0, predicted=335.0
# expected=406.0, predicted=394.3
# expected=390.0, predicted=420.8
# expected=375.0, predicted=383.7
# expected=361.0, predicted=378.5
# expected=405.0, predicted=340.0
# expected=466.0, predicted=404.6
# expected=485.0, predicted=455.3
# expected=474.0, predicted=494.5
# expected=415.0, predicted=434.0
# expected=373.0, predicted=392.9
# expected=360.0, predicted=406.0
# expected=332.0, predicted=366.1
# expected=371.0, predicted=327.9
# expected=388.0, predicted=385.1
# expected=387.0, predicted=409.2
# expected=354.0, predicted=371.1
# expected=350.0, predicted=355.4
# expected=332.0, predicted=367.2
# expected=336.0, predicted=337.4
# expected=370.0, predicted=342.9
# expected=407.0, predicted=356.8
# expected=428.0, predicted=416.7
# expected=354.0, predicted=405.4
# expected=326.0, predicted=354.4
# expected=347.0, predicted=332.8
# expected=321.0, predicted=339.2
# expected=361.0, predicted=349.6
# expected=389.0, predicted=347.6
# expected=378.0, predicted=364.8
# expected=335.0, predicted=380.9
# expected=327.0, predicted=325.0
# expected=355.0, predicted=339.0
# expected=368.0, predicted=376.9
# expected=356.0, predicted=377.1
# expected=406.0, predicted=373.9
# expected=437.0, predicted=415.8
# expected=344.0, predicted=436.3
# expected=356.0, predicted=344.1
# expected=352.0, predicted=380.5
# expected=329.0, predicted=371.5
# expected=336.0, predicted=332.5
# expected=366.0, predicted=344.3
# expected=429.0, predicted=365.8
# expected=342.0, predicted=438.5
# expected=346.0, predicted=334.7
# expected=337.0, predicted=370.6
# expected=311.0, predicted=365.0
# expected=370.0, predicted=337.3
# expected=390.0, predicted=366.0
# expected=409.0, predicted=383.1
# expected=316.0, predicted=415.8
# expected=316.0, predicted=313.2
# expected=348.0, predicted=313.8
# expected=340.0, predicted=371.9
# expected=363.0, predicted=360.9
# expected=402.0, predicted=366.1
# expected=404.0, predicted=383.9
# expected=333.0, predicted=375.2
# expected=358.0, predicted=316.6
# expected=334.0, predicted=374.1
# expected=321.0, predicted=343.4
# expected=316.0, predicted=353.0
# expected=330.0, predicted=321.8
# expected=391.0, predicted=347.5
# expected=326.0, predicted=406.2
# expected=297.0, predicted=334.2
# expected=281.0, predicted=295.1
# expected=289.0, predicted=308.1
# expected=301.0, predicted=291.5
# expected=330.0, predicted=341.4
# expected=348.0, predicted=356.8
# expected=314.0, predicted=364.4
# expected=331.0, predicted=329.6
# expected=303.0, predicted=341.0
# expected=311.0, predicted=307.4
# expected=318.0, predicted=344.2
# expected=317.0, predicted=349.9
# expected=368.0, predicted=327.6
# expected=327.0, predicted=366.5
# expected=323.0, predicted=341.0
# expected=328.0, predicted=332.1
# expected=351.0, predicted=341.2
# expected=348.0, predicted=363.2
# expected=352.0, predicted=354.5
# expected=332.0, predicted=353.0
# expected=275.0, predicted=338.4
# expected=271.0, predicted=295.8
# expected=289.0, predicted=285.1
# expected=305.0, predicted=294.3
# expected=308.0, predicted=330.6
# expected=350.0, predicted=332.1
# expected=379.0, predicted=360.5
# expected=288.0, predicted=386.9
# expected=299.0, predicted=304.0
# expected=292.0, predicted=322.2
# expected=298.0, predicted=310.9
# expected=293.0, predicted=316.0
# expected=300.0, predicted=305.5
# expected=316.0, predicted=332.3
# expected=273.0, predicted=323.1
# expected=283.0, predicted=294.6
# expected=311.0, predicted=295.4
# expected=267.0, predicted=340.0
# expected=284.0, predicted=270.1
# expected=300.0, predicted=289.3
# expected=338.0, predicted=328.1

# %% [markdown]
# ### Complex Approach
#
# Take more iterative approach, using only the 2016 data as the training and 2017 - 2020 is the training set; walking forward, in hopes of generating a better understanding of patterns.
#
# What is an epoch in this approach?
